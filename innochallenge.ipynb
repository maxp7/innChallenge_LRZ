# %%
import csv
import numpy as np
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense

def read_training(filename):
    result = list()
    Windwowsize = 20
    nextstep = 1
    with open(filename) as csv_file:
        reader = csv.reader(csv_file, delimiter=';')
        zeilennummer = 0
        rec0 = []
        rec1 = []
        rec2 = []
        rec3 = []
        rec4 = []
        rec5 = []
        rec6 = []
        rec7 = []
        rec8 = []
        rec9 = []
        rec10 = []
        rec11 = []
        rec12 = []
        rec13 = []
        rec14 = []
        rec15 = []
        rec16 = []
        rec17 = []
        rec18 = []
        rec19 = []
        newRes = []
        sec = ()
        for Sek,Act,CPU,Ker,tems0,enes0,tems1,enes1,mem,brains,Xmit,runApp,runAppID in reader:
            if zeilennummer >= 1:
                rec0 = rec1
                rec1 = rec2
                rec2 = rec3
                rec3 = rec4
                rec4 = rec5
                rec5 = rec6
                rec6 = rec7
                rec7 = rec8
                rec8 = rec9
                rec9 = rec10
                rec10 = rec11
                rec11 = rec12
                rec12 = rec13
                rec13 = rec14
                rec14 = rec15
                rec15 = rec16
                rec16 = rec17
                rec17 = rec18
                rec18 = rec19
                rec19 = [int(Act)]
                rec19.append(int(CPU))
                #rec19.append(int(Ker))
                rec19.append(int(tems0))
                rec19.append(int(enes0))
                rec19.append(int(tems1))
                rec19.append(int(enes1))
                rec19.append(int(mem))
                #rec19.append(int(brains))
                #rec19.append(int(Xmit))
                
            if zeilennummer >= 21:
                newres = []
                newres.extend(rec0)
                newres.extend(rec1)
                newres.extend(rec2)
                newres.extend(rec3)
                newres.extend(rec4)
                newres.extend(rec5)
                newres.extend(rec6)
                newres.extend(rec7)
                newres.extend(rec8)
                newres.extend(rec9)
                newres.extend(rec10)
                newres.extend(rec11)
                newres.extend(rec12)
                newres.extend(rec13)
                newres.extend(rec14)
                newres.extend(rec15)
                newres.extend(rec16)
                newres.extend(rec17)
                newres.extend(rec18)
                newres.extend(rec19)
                result.append(newres)
                
            zeilennummer += 1 
        return result
            
def read_lable(filename):
    result = list()
    with open(filename) as csv_file:
        reader = csv.reader(csv_file, delimiter=';')
        rec0 = []
        rec1 = []
        rec2 = []
        rec3 = []
        rec4 = []
        rec5 = []
        rec6 = []
        rec7 = []
        rec8 = []
        rec9 = []
        rec10 = []
        zeilennummer = 0
        for Sek,Act,CPU,Ker,tems0,enes0,tems1,enes1,mem,brains,Xmit,runApp,runAppID in reader:
            
            if zeilennummer >= 21:
                result.append(int(runAppID))
                
            zeilennummer += 1      
        return result

# Training Node 0
print('Loading Data Node0')
x_train = np.array(read_training("./innoChall/Data_Prepared_node0.csv"))
y_train = np.array(read_lable("./innoChall/Data_Prepared_node0.csv"))

y_train = to_categorical(y_train)

# defining model    
print('Defining Model')
model = Sequential()

model.add(Dense(1000, activation="sigmoid", input_shape=(len(x_train[0]),)))
#model.add(Dense(333, activation="sigmoid"))
#model.add(Dense(220, activation="sigmoid"))
model.add(Dense(7, activation="sigmoid"))

model.compile(optimizer="sgd", loss="categorical_crossentropy", metrics=["accuracy"])

print('Training Data Node0')
model.fit(
    x_train.reshape(len(x_train), len(x_train[0])),
    y_train,
    epochs=10,
    batch_size=5)

# Training Node 1    
print('Loading Data Node1')
x_train = np.array(read_training("./innoChall/Data_Prepared_node1.csv"))
y_train = np.array(read_lable("./innoChall/Data_Prepared_node1.csv"))

y_train = to_categorical(y_train)

model = Sequential()

model.add(Dense(1000, activation="sigmoid", input_shape=(len(x_train[0]),)))
#model.add(Dense(333, activation="sigmoid"))
#model.add(Dense(220, activation="sigmoid"))
model.add(Dense(7, activation="sigmoid"))

model.compile(optimizer="sgd", loss="categorical_crossentropy", metrics=["accuracy"])

print('Training Data Node1')
model.fit(
    x_train.reshape(len(x_train), len(x_train[0])),
    y_train,
    epochs=10,
    batch_size=5)

# Training Node 2    
print('Loading Data Node2')
x_train = np.array(read_training("./innoChall/Data_Prepared_node2.csv"))
y_train = np.array(read_lable("./innoChall/Data_Prepared_node2.csv"))

y_train = to_categorical(y_train)


model = Sequential()

model.add(Dense(1000, activation="sigmoid", input_shape=(len(x_train[0]),)))
#model.add(Dense(333, activation="sigmoid"))
#model.add(Dense(220, activation="sigmoid"))
model.add(Dense(7, activation="sigmoid"))

model.compile(optimizer="sgd", loss="categorical_crossentropy", metrics=["accuracy"])

print('Training Data Node2')
model.fit(
    x_train.reshape(len(x_train), len(x_train[0])),
    y_train,
    epochs=10,
    batch_size=5)
# Out:
# Loading Data Node0
# Defining Model
# Training Data Node0
# Epoch 1/10
# 15586/15586 [==============================] - 17s 1ms/step - loss: 1.6390 - accuracy: 0.3305
# Epoch 2/10
# 15586/15586 [==============================] - 17s 1ms/step - loss: 1.5585 - accuracy: 0.3487
# Epoch 3/10
# 15586/15586 [==============================] - 17s 1ms/step - loss: 1.5187 - accuracy: 0.3564
# Epoch 4/10
# 15586/15586 [==============================] - 17s 1ms/step - loss: 1.4841 - accuracy: 0.3741
# Epoch 5/10
# 15586/15586 [==============================] - 16s 1ms/step - loss: 1.4562 - accuracy: 0.3823
# Epoch 6/10
# 15586/15586 [==============================] - 17s 1ms/step - loss: 1.4341 - accuracy: 0.3899
# Epoch 7/10
# 15586/15586 [==============================] - 17s 1ms/step - loss: 1.4176 - accuracy: 0.3943
# Epoch 8/10
# 15586/15586 [==============================] - 17s 1ms/step - loss: 1.4028 - accuracy: 0.3986
# Epoch 9/10
# ...

# %% [raw]
# #X_train =
# #for row in X_train:
# #    print(row)
# print(y_train)
# print(len(y_train[1]))
# # x_train.reshape(len(x_train), len(x_train[0]))

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 26101900094626216
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 12120554802555329075
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 14378262954540829609
# physical_device_desc: "device: XLA_GPU device"
# ]
